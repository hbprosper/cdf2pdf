# %%
import numpy as np; import pandas as pd
import scipy as sp; import scipy.stats as st
import torch; import torch.nn as nn
#use numba's just-in-time compiler to speed things up
from sklearn.preprocessing import StandardScaler; from sklearn.model_selection import train_test_split
import matplotlib as mp; import matplotlib.pyplot as plt; 
#reset matplotlib stle/parameters
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
#plt.style.use('seaborn-deep')
mp.rcParams['agg.path.chunksize'] = 10000
mp.rcParams['axes.linewidth'] = 1
font_legend = 15; font_axes=15
# %matplotlib inline
from joblib import  Memory

import copy; import sys; import os
from IPython.display import Image, display
from importlib import import_module

# %%
FONTSIZE=18
font = {'family': 'serif', 'weight':'normal', 'size':FONTSIZE}
mp.rc('font', **font)
mp.rc('text',usetex=True)

# %%
device  = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %%
def debug(func):
    """Print the function signature and return value"""
    import functools

    @functools.wraps(func)
    def wrapper_debug(*args, **kwargs):
        args_repr = [repr(a) for a in args]
        kwargs_repr = [f"{k}={v!r}" for k, v in kwargs.items()]
        signature = ", ".join(args_repr + kwargs_repr)
        print(f"Calling {func.__name__}({signature})")
        values = func(*args, **kwargs)
        print(f"{func.__name__!r} returned {values!r}")
        return values

    return wrapper_debug

def theta_hat_func(n,m, MLE):
       #n,m are integer arrays
    if MLE:
        theta_hat = n-m
    else:
        # non-MLE
        # theta_hat = n-m
        # theta_hat = (theta_hat) * (theta_hat > 0)
        theta_hat = np.where(n>m, n-m, 0)
         
    return theta_hat


def L_prof_global(n,m, MLE):
    #n,m integer arrays
    # nu_hat = m, if theta_hat = theta_hat_MLE
    # nu_hat  =  (m+n)/2 if theta_hat = n-m
    # nu_hat = 0  if theta_hat != n-m
    theta_hat=theta_hat_func(n,m,MLE)
    # print('n-m ',  n-m)
    if MLE:
        # i.e. if theta_hat = n-m
        # assert theta_hat==n-m
        nu_hat = m
    else:
        nu_hat = np.where(theta_hat ==0, (m+n)/2, m)

    p1=st.poisson.pmf(n, theta_hat+nu_hat)
    p2 = st.poisson.pmf(m, nu_hat)
    return p1*p2

def L_theta_nu(n,m,theta,nu):
    p1 = st.poisson.pmf(n, theta+nu)
    p2 = st.poisson.pmf(m, nu)
    return p1*p2
def lambda_test_2d(n,m, theta, nu, MLE):
    Ln= L_theta_nu(n,m,theta,nu)
    
    Ld= L_prof_global(n,m, MLE)
    eps=1e-20
    Ld=Ld+eps
    lambda_  = -2*np.log(Ln/Ld)
    return np.array(lambda_)

# %%
def D(Nmin, Nmax, Mmin, Mmax):
    return [(n,m) for N in range(Nmin, Nmax) for m in range(Mmin, Mmax)]

# %%
def save_model(model, PARAMS, pth_string):
    """pth string is the name of the pth file which is a dictionary of dictionaries"""
    models_path = os.path.join(os.getcwd(), '../models')
    PATH=os.path.join(models_path, pth_string)
    print(f'saving model with th string : {pth_string}\n')
    torch.save({'PARAMS': PARAMS,
                'model_state_dict': model.state_dict()},
                PATH)
    # print(model)

# %%
def make_binned_X(X_min, X_max, Nbins):
    X_step = (X_max-X_min) / Nbins
    bins = np.arange(X_min, X_max+X_step, X_step)
    bin_centers = (bins[1:] + bins[:-1])/2
    return np.array(bin_centers)

def make_eval_data_2d_with_NM(Bprime, N, M, nbins_theta, nbins_nu):
    """Make evaluation data composed of: binned theta and nu, and discrete N and M,
    and optionally theta_hat. The theta hat argument accpts an MLE boolean, therefore
    if trained on MLE data, the theta_hat that we use for evaluation is just 
    n-m, including negative values.
    The return value of this function is used as the "eval_data" tensor below
    
    with lambda_D or with NM"""
    #if MLE true, load the model that was trained on MLE data and vice versa
    # N, M = D
    # nbins=NBINS
    # thetamin,thetamax=0,20
    train_df = load_2d_train_df(MLE=False, with_lambda_D=True)
    
    THETA_bin_centers = make_binned_X(X_min=train_df['theta'].min(),
                                      X_max=train_df['theta'].max(), 
                                      Nbins=nbins_theta)
        
    NU_bin_centers = make_binned_X(X_min=train_df['nu'].min(),
                                  X_max=train_df['nu'].max(), 
                                  Nbins=nbins_nu)
        
    # tensor = torch.Tensor([
                           # [x, y, theta_hat(N, M, MLE=True), N, M] 
                           # for (x,y) in zip(THETA_bin_centers,NU_bin_centers)
                          # ])

    tensor = torch.Tensor([
                       [x, y, theta_hat(N, M, MLE=True), N, M] 
                       for x in THETA_bin_centers for y in NU_bin_centers
                      ])

    #zip only traverses the lists monotonically, so experiment to use cross to take every combination of the two lists
    
    return tensor, THETA_bin_centers.ravel(), NU_bin_centers.ravel()

# %%
class SiLURegressionModel(nn.Module):
    #inherit from the super class
    def __init__(self, nfeatures, ntargets, nlayers, hidden_size, dropout):
        super().__init__()
        layers = []
        for _ in range(nlayers):
            if len(layers) ==0:
                #inital layer has to have size of input features as its input layer
                #its output layer can have any size but it must match the size of the input layer of the next linear layer
                #here we choose its output layer as the hidden size (fully connected)
                layers.append(nn.Linear(nfeatures, hidden_size))
                #batch normalization
                # layers.append(nn.BatchNorm1d(hidden_size))
                #Dropout seems to worsen model performance
                layers.append(nn.Dropout(dropout))
                #ReLU activation 
                layers.append(nn.SiLU())
            else:
                #if this is not the first layer (we dont have layers)
                layers.append(nn.Linear(hidden_size, hidden_size))
                # layers.append(nn.BatchNorm1d(hidden_size))
                #Dropout seems to worsen model performance
                layers.append(nn.Dropout(dropout))
                layers.append(nn.SiLU())
                #output layer:
        layers.append(nn.Linear(hidden_size, ntargets)) 

        # ONLY IF ITS A CLASSIFICATION, ADD SIGMOID
        layers.append(nn.Sigmoid())
            #we have defined sequential model using the layers in oulist 
        self.model = nn.Sequential(*layers)

    
    def forward(self, x):
        return self.model(x)

# %%
@debug
def load_untrained_model(PARAMS):
    """Load an untrained model (with weights initiatted) according to model paramateters in the 
    PARAMS dictionary

    Args:
        PARAMS (dict): dictionary of model/training parameters: i.e. hyperparameters and training parameters.

    Returns:
        utils.RegularizedRegressionModel object
    """
    model = SiLURegressionModel(
        nfeatures=PARAMS['NFEATURES'],
        ntargets=1,
        nlayers=PARAMS["n_layers"],
        hidden_size=PARAMS["hidden_size"],
        dropout=PARAMS["dropout"],
        # activation=PARAMS["activation"]
    )
    # model.apply(initialize_weights)
    print('INITIATED UNTRAINED MODEL:',
          # model
         )
    # print(model)
    return model

# %% [markdown]
# # Step 1: define model parameters for MLE=False model

# %%
PARAMS_lambdaD_nonMLE_SILU = {
"n_layers": int(12),
"hidden_size": int(12),
"dropout": float(0.13),
"NFEATURES":int(3),
"activation": "SiLU",
'optimizer_name':'NAdam',
    # 'optimizer_name':'RMSprop',
'starting_learning_rate':float(0.0006),
'momentum':float(0.9),
'batch_size':int(256*2),
'n_iterations': int(1e5),
'traces_step':int(100),
'L2':float(0.1),
'MLE':False,
'with_lambda_D':True,
'pth_string':'FEB_20_model_lambda_D_nonMLE_SILU.pth'
}

# %% [markdown]
# # step 2: load untrained model for MLE=False

# %%
untrained_SiLU_model_nonMLE = load_untrained_model(PARAMS_lambdaD_nonMLE_SILU)
# Out:
# Calling load_untrained_model({'n_layers': 12, 'hidden_size': 12, 'dropout': 0.13, 'NFEATURES': 3, 'activation': 'SiLU', 'optimizer_name': 'NAdam', 'starting_learning_rate': 0.0006, 'momentum': 0.9, 'batch_size': 512, 'n_iterations': 100000, 'traces_step': 100, 'L2': 0.1, 'MLE': False, 'with_lambda_D': True, 'pth_string': 'FEB_20_model_lambda_D_nonMLE_SILU.pth'})
# INITIATED UNTRAINED MODEL:
# 'load_untrained_model' returned SiLURegressionModel(
#   (model): Sequential(
#     (0): Linear(in_features=3, out_features=12, bias=True)
#     (1): Dropout(p=0.13, inplace=False)
#     (2): SiLU()
#     (3): Linear(in_features=12, out_features=12, bias=True)
#     (4): Dropout(p=0.13, inplace=False)
#     (5): SiLU()
#     (6): Linear(in_features=12, out_features=12, bias=True)
#     (7): Dropout(p=0.13, inplace=False)
#     (8): SiLU()
#     (9): Linear(in_features=12, out_features=12, bias=True)
#     (10): Dropout(p=0.13, inplace=False)
#     (11): SiLU()
#     (12): Linear(in_features=12, out_features=12, bias=True)
#     (13): Dropout(p=0.13, inplace=False)
#     (14): SiLU()
#     (15): Linear(in_features=12, out_features=12, bias=True)
#     (16): Dropout(p=0.13, inplace=False)
#     (17): SiLU()
#     (18): Linear(in_features=12, out_features=12, bias=True)
#     (19): Dropout(p=0.13, inplace=False)
#     (20): SiLU()
#     (21): Linear(in_features=12, out_features=12, bias=True)
#     (22): Dropout(p=0.13, inplace=False)
#     (23): SiLU()
#     (24): Linear(in_features=12, out_features=12, bias=True)
#     (25): Dropout(p=0.13, inplace=False)
#     (26): SiLU()
#     (27): Linear(in_features=12, out_features=12, bias=True)
#     (28): Dropout(p=0.13, inplace=False)
#     (29): SiLU()
#     (30): Linear(in_features=12, out_features=12, bias=True)
#     (31): Dropout(p=0.13, inplace=False)
#     (32): SiLU()
#     (33): Linear(in_features=12, out_features=12, bias=True)
#     (34): Dropout(p=0.13, inplace=False)
#     (35): SiLU()
#     (36): Linear(in_features=12, out_features=1, bias=True)
#     (37): Sigmoid()
#   )
# )

# %% [markdown]
# # Step 3: Load Trained model for MLE=False

# %%
def load_model(model, PARAMS, pth_string):
    models_path = os.path.join(os.getcwd(), '../models')
    PATH=os.path.join(models_path, pth_string)
    model = SiLURegressionModel(
        nfeatures=PARAMS['NFEATURES'],
        ntargets=1,
        nlayers=PARAMS["n_layers"],
        hidden_size=PARAMS["hidden_size"],
        dropout=PARAMS["dropout"]
    )
    checkpoint = torch.load(PATH)
    print('INITIATED MODEL:',  model)
    
    model.load_state_dict(checkpoint['model_state_dict'])
    print(f'loading model with th string : {pth_string}\n')    
    # print(model)
    
    return model

# %%
# untrained_SiLU_model = load_untrained_model(PARAMS_lambdaD_nonMLE_SILU)

trained_SiLU_model_nonMLE = load_model(model = untrained_SiLU_model_nonMLE, 
                                PARAMS=PARAMS_lambdaD_nonMLE_SILU,
                   pth_string=PARAMS_lambdaD_nonMLE_SILU["pth_string"])
# Out:
# INITIATED MODEL: SiLURegressionModel(
#   (model): Sequential(
#     (0): Linear(in_features=3, out_features=12, bias=True)
#     (1): Dropout(p=0.13, inplace=False)
#     (2): SiLU()
#     (3): Linear(in_features=12, out_features=12, bias=True)
#     (4): Dropout(p=0.13, inplace=False)
#     (5): SiLU()
#     (6): Linear(in_features=12, out_features=12, bias=True)
#     (7): Dropout(p=0.13, inplace=False)
#     (8): SiLU()
#     (9): Linear(in_features=12, out_features=12, bias=True)
#     (10): Dropout(p=0.13, inplace=False)
#     (11): SiLU()
#     (12): Linear(in_features=12, out_features=12, bias=True)
#     (13): Dropout(p=0.13, inplace=False)
#     (14): SiLU()
#     (15): Linear(in_features=12, out_features=12, bias=True)
#     (16): Dropout(p=0.13, inplace=False)
#     (17): SiLU()
#     (18): Linear(in_features=12, out_features=12, bias=True)
#     (19): Dropout(p=0.13, inplace=False)
#     (20): SiLU()
#     (21): Linear(in_features=12, out_features=12, bias=True)
#     (22): Dropout(p=0.13, inplace=False)
#     (23): SiLU()
#     (24): Linear(in_features=12, out_features=12, bias=True)
#     (25): Dropout(p=0.13, inplace=False)
#     (26): SiLU()
#     (27): Linear(in_features=12, out_features=12, bias=True)
#     (28): Dropout(p=0.13, inplace=False)
#     (29): SiLU()
#     (30): Linear(in_features=12, out_features=12, bias=True)
#     (31): Dropout(p=0.13, inplace=False)
#     (32): SiLU()
#     (33): Linear(in_features=12, out_features=12, bias=True)
#     (34): Dropout(p=0.13, inplace=False)
#     (35): SiLU()
#     (36): Linear(in_features=12, out_features=1, bias=True)
#     (37): Sigmoid()
#   )
# )
# loading model with th string : FEB_20_model_lambda_D_nonMLE_SILU.pth
#
# SiLURegressionModel(
#   (model): Sequential(
#     (0): Linear(in_features=3, out_features=12, bias=True)
#     (1): Dropout(p=0.13, inplace=False)
#     (2): SiLU()
#     (3): Linear(in_features=12, out_features=12, bias=True)
#     (4): Dropout(p=0.13, inplace=False)
#     (5): SiLU()
#     (6): Linear(in_features=12, out_features=12, bias=True)
#     (7): Dropout(p=0.13, inplace=False)
#     (8): SiLU()
#     (9): Linear(in_features=12, out_features=12, bias=True)
#     (10): Dropout(p=0.13, inplace=False)
#     (11): SiLU()
#     (12): Linear(in_features=12, out_features=12, bias=True)
#     (13): Dropout(p=0.13, inplace=False)
#     (14): SiLU()
#     (15): Linear(in_features=12, out_features=12, bias=True)
#     (16): Dropout(p=0.13, inplace=False)
#     (17): SiLU()
#     (18): Linear(in_features=12, out_features=12, bias=True)
#     (19): Dropout(p=0.13, inplace=False)
#     (20): SiLU()
#     (21): Linear(in_features=12, out_features=12, bias=True)
#     (22): Dropout(p=0.13, inplace=False)
#     (23): SiLU()
#     (24): Linear(in_features=12, out_features=12, bias=True)
#     (25): Dropout(p=0.13, inplace=False)
#     (26): SiLU()
#     (27): Linear(in_features=12, out_features=12, bias=True)
#     (28): Dropout(p=0.13, inplace=False)
#     (29): SiLU()
#     (30): Linear(in_features=12, out_features=12, bias=True)
#     (31): Dropout(p=0.13, inplace=False)
#     (32): SiLU()
#     (33): Linear(in_features=12, out_features=12, bias=True)
#     (34): Dropout(p=0.13, inplace=False)
#     (35): SiLU()
#     (36): Linear(in_features=12, out_features=1, bias=True)
#     (37): Sigmoid()
#   )
# )

# %% [markdown]
# # Step 4: define model parameters for MLE=True model

# %%
PARAMS_lambdaD_MLE_SILU = {
"n_layers": int(12),
"hidden_size": int(12),
"dropout": float(0.13),
"NFEATURES":int(3),
"activation": "SiLU",
'optimizer_name':'NAdam',
    # 'optimizer_name':'RMSprop',
'starting_learning_rate':float(0.0006),
'momentum':float(0.9),
'batch_size':int(256*2),
'n_iterations': int(6e4),
'traces_step':int(100),
'L2':float(0.1),
'MLE':True,
'with_lambda_D':True,
'pth_string':'FEB_20_model_lambda_D_MLE_SILU.pth'
}

# %% [markdown]
# # step 5: load untrained model for MLE=True

# %%
untrained_SiLU_model_MLE = load_untrained_model(PARAMS_lambdaD_MLE_SILU)
# Out:
# Calling load_untrained_model({'n_layers': 12, 'hidden_size': 12, 'dropout': 0.13, 'NFEATURES': 3, 'activation': 'SiLU', 'optimizer_name': 'NAdam', 'starting_learning_rate': 0.0006, 'momentum': 0.9, 'batch_size': 512, 'n_iterations': 60000, 'traces_step': 100, 'L2': 0.1, 'MLE': True, 'with_lambda_D': True, 'pth_string': 'FEB_20_model_lambda_D_MLE_SILU.pth'})
# INITIATED UNTRAINED MODEL:
# 'load_untrained_model' returned SiLURegressionModel(
#   (model): Sequential(
#     (0): Linear(in_features=3, out_features=12, bias=True)
#     (1): Dropout(p=0.13, inplace=False)
#     (2): SiLU()
#     (3): Linear(in_features=12, out_features=12, bias=True)
#     (4): Dropout(p=0.13, inplace=False)
#     (5): SiLU()
#     (6): Linear(in_features=12, out_features=12, bias=True)
#     (7): Dropout(p=0.13, inplace=False)
#     (8): SiLU()
#     (9): Linear(in_features=12, out_features=12, bias=True)
#     (10): Dropout(p=0.13, inplace=False)
#     (11): SiLU()
#     (12): Linear(in_features=12, out_features=12, bias=True)
#     (13): Dropout(p=0.13, inplace=False)
#     (14): SiLU()
#     (15): Linear(in_features=12, out_features=12, bias=True)
#     (16): Dropout(p=0.13, inplace=False)
#     (17): SiLU()
#     (18): Linear(in_features=12, out_features=12, bias=True)
#     (19): Dropout(p=0.13, inplace=False)
#     (20): SiLU()
#     (21): Linear(in_features=12, out_features=12, bias=True)
#     (22): Dropout(p=0.13, inplace=False)
#     (23): SiLU()
#     (24): Linear(in_features=12, out_features=12, bias=True)
#     (25): Dropout(p=0.13, inplace=False)
#     (26): SiLU()
#     (27): Linear(in_features=12, out_features=12, bias=True)
#     (28): Dropout(p=0.13, inplace=False)
#     (29): SiLU()
#     (30): Linear(in_features=12, out_features=12, bias=True)
#     (31): Dropout(p=0.13, inplace=False)
#     (32): SiLU()
#     (33): Linear(in_features=12, out_features=12, bias=True)
#     (34): Dropout(p=0.13, inplace=False)
#     (35): SiLU()
#     (36): Linear(in_features=12, out_features=1, bias=True)
#     (37): Sigmoid()
#   )
# )

# %% [markdown]
# # Step 6: Load Trained model for MLE=True

# %%
# untrained_SiLU_model = load_untrained_model(PARAMS_lambdaD_nonMLE_SILU)

trained_SiLU_model_MLE = load_model(model = untrained_SiLU_model_MLE, 
                                PARAMS=PARAMS_lambdaD_MLE_SILU,
                   pth_string=PARAMS_lambdaD_MLE_SILU["pth_string"])
# Out:
# INITIATED MODEL: SiLURegressionModel(
#   (model): Sequential(
#     (0): Linear(in_features=3, out_features=12, bias=True)
#     (1): Dropout(p=0.13, inplace=False)
#     (2): SiLU()
#     (3): Linear(in_features=12, out_features=12, bias=True)
#     (4): Dropout(p=0.13, inplace=False)
#     (5): SiLU()
#     (6): Linear(in_features=12, out_features=12, bias=True)
#     (7): Dropout(p=0.13, inplace=False)
#     (8): SiLU()
#     (9): Linear(in_features=12, out_features=12, bias=True)
#     (10): Dropout(p=0.13, inplace=False)
#     (11): SiLU()
#     (12): Linear(in_features=12, out_features=12, bias=True)
#     (13): Dropout(p=0.13, inplace=False)
#     (14): SiLU()
#     (15): Linear(in_features=12, out_features=12, bias=True)
#     (16): Dropout(p=0.13, inplace=False)
#     (17): SiLU()
#     (18): Linear(in_features=12, out_features=12, bias=True)
#     (19): Dropout(p=0.13, inplace=False)
#     (20): SiLU()
#     (21): Linear(in_features=12, out_features=12, bias=True)
#     (22): Dropout(p=0.13, inplace=False)
#     (23): SiLU()
#     (24): Linear(in_features=12, out_features=12, bias=True)
#     (25): Dropout(p=0.13, inplace=False)
#     (26): SiLU()
#     (27): Linear(in_features=12, out_features=12, bias=True)
#     (28): Dropout(p=0.13, inplace=False)
#     (29): SiLU()
#     (30): Linear(in_features=12, out_features=12, bias=True)
#     (31): Dropout(p=0.13, inplace=False)
#     (32): SiLU()
#     (33): Linear(in_features=12, out_features=12, bias=True)
#     (34): Dropout(p=0.13, inplace=False)
#     (35): SiLU()
#     (36): Linear(in_features=12, out_features=1, bias=True)
#     (37): Sigmoid()
#   )
# )
# loading model with th string : FEB_20_model_lambda_D_MLE_SILU.pth
#
# SiLURegressionModel(
#   (model): Sequential(
#     (0): Linear(in_features=3, out_features=12, bias=True)
#     (1): Dropout(p=0.13, inplace=False)
#     (2): SiLU()
#     (3): Linear(in_features=12, out_features=12, bias=True)
#     (4): Dropout(p=0.13, inplace=False)
#     (5): SiLU()
#     (6): Linear(in_features=12, out_features=12, bias=True)
#     (7): Dropout(p=0.13, inplace=False)
#     (8): SiLU()
#     (9): Linear(in_features=12, out_features=12, bias=True)
#     (10): Dropout(p=0.13, inplace=False)
#     (11): SiLU()
#     (12): Linear(in_features=12, out_features=12, bias=True)
#     (13): Dropout(p=0.13, inplace=False)
#     (14): SiLU()
#     (15): Linear(in_features=12, out_features=12, bias=True)
#     (16): Dropout(p=0.13, inplace=False)
#     (17): SiLU()
#     (18): Linear(in_features=12, out_features=12, bias=True)
#     (19): Dropout(p=0.13, inplace=False)
#     (20): SiLU()
#     (21): Linear(in_features=12, out_features=12, bias=True)
#     (22): Dropout(p=0.13, inplace=False)
#     (23): SiLU()
#     (24): Linear(in_features=12, out_features=12, bias=True)
#     (25): Dropout(p=0.13, inplace=False)
#     (26): SiLU()
#     (27): Linear(in_features=12, out_features=12, bias=True)
#     (28): Dropout(p=0.13, inplace=False)
#     (29): SiLU()
#     (30): Linear(in_features=12, out_features=12, bias=True)
#     (31): Dropout(p=0.13, inplace=False)
#     (32): SiLU()
#     (33): Linear(in_features=12, out_features=12, bias=True)
#     (34): Dropout(p=0.13, inplace=False)
#     (35): SiLU()
#     (36): Linear(in_features=12, out_features=1, bias=True)
#     (37): Sigmoid()
#   )
# )

# %% [markdown]
# # Summary: We have loaded `trained_SiLU_model_nonMLE` and `trained_SiLU_model_MLE`

# %%
class TrainedModel:
    def __init__(self, model):
        self.model = model

    def __cdf(self, x):
        # convert to a tensor and compute
 
        X = torch.Tensor(x)#.transpose(1, 0)
            
        X.requires_grad_(True)
        
        self.model.eval() 
        
        return self.model(X), X 
        
    def cdf(self, x): 
        F, _ = self.__cdf(x)
        
        Y = F.view(-1).detach().numpy()
        if len(Y) == 1:
            Y = Y[0]
        return Y

        
        Y = F.view(-1).detach().numpy()
        if len(Y) == 1:
            Y = Y[0]
        return Y
    
    def numerical_deriv(self,x):
        h=1E-3
        F_h = self.cdf(x+h)
        F = self.cdf(x)
        deriv = (F_h-F)/h
        return deriv
        

    def pdf(self, x):
        F, X = self.__cdf(x)

        dFdX = torch.autograd.grad(outputs=F, inputs=X, 
                               grad_outputs=torch.ones_like(F),
                               #allow_unused=True, 
                               #retain_graph=True, 
                               create_graph=True)[0]
    
        # Y = dFdX.view(-1).detach().numpy()
        Y = dFdX.detach().numpy()
        if len(Y) == 1:
            Y = Y[0]
        return Y.T[-1]

# %%
def run_sim(theta, nu, MLE, lambda_size):
    """Sample n ~ Pois(theta+nu), 
              m ~ Pois(nu), 
    and compute 
              lambda(theta, n, m)
              
    return: (n, m, lambda_), where each are np arrays of length lambda_size
    """
    n = st.poisson.rvs(theta+nu, size=lambda_size)
    m = st.poisson.rvs(nu, size=lambda_size)
    lambda_ = lambda_test_2d(theta=theta, nu=nu, n=n, m=m, MLE=MLE)
    return (n, m, lambda_)

def run_sims(points, MLE):
    """
    Run an entire simulation, that is, generate n and m from 
    run_sim above, and calculate lambda, for
    
    input: a tuple of (theta, nu) scalars
    
    Reurns:df, lambda_results
    
    where lambda_results is a list of tuples 
        (n, m, lambda_, theta, nu)
    and df is just a dataframe of [n,m,lambda,theta,nu]

    """
    lambda_results=[]
    df=pd.DataFrame()
    for p in points:
        theta, nu = p
        df['theta']=theta
        df['nu']=nu
        n, m, lambda_ = run_sim(theta, nu, MLE, lambda_size =chi2_exp_size)
        df['n'] = n
        df['m'] = m
        df['lambda']=lambda_
        lambda_results.append((n, m, lambda_, theta, nu))
    
        print( '\n \n (theta, nu) =  (%.f, %.f) \n ' % (theta, nu) )
        print(f'\t \t with associated n =  {n}, \n \n \t \t m = {m}, \n \n \t \t lambda = {lambda_}'  )
    return df, lambda_results

def plot_all(lambda_, theta, nu, ax_l, MLE):
    """Histogram the CDF of  lambda_t = -2log(Lp(theta)/Lp(theta_hat)), 
    for a given (fixed) theta and nu.
    Also, plot the actual CDF of a chi^2 distribution with 1 free parameter 
    (since only theta is left after we profile nu) """
    ftsize = 16; xmin= 0; xmax= 10
    ymin= 0; ymax= 1
    x_range = (xmin, xmax)
    y_range = (ymin, ymax)
    # X = np.empty((len(lambda_), 3))
    # X[:,0] = np.ones_like(theta)*theta
    # X[:,1] = np.ones_like(nu)*nu
    
    # X[:,2] = np.linspace(0,10,len(lambda_))
    BINS=30
    if MLE==True:
        tmodel = TrainedModel(trained_SiLU_model_MLE)
    else:
        tmodel = TrainedModel(trained_SiLU_model_nonMLE)
        
    
    ax_l[0].set_ylabel(r'$F(\lambda)$', fontsize=ftsize)
    ##########HISTOGRAM CDF OF LAMBDA####################
    
    yc, low_edge, _ = ax_l[0].hist(lambda_, bins=BINS, range=x_range,
    color=(0.8,0.8,0.9),
    density=True, cumulative=True,
    histtype='stepfilled', edgecolor='black', label=r'$F(\lambda)$')
    print(yc, low_edge)
    ############################################################
    ########### HISTOGRAM CDF OF THE CHI2 OF OF X WITH 1 DOF
    #x is not theta, that's the whole point of Wilks thm, x is an arbitrary RV

    x = (low_edge[1:]+low_edge[:-1])/2
    #x = np.arange(0, xmax, 0.2)
    assert(len(x) == len(yc))
    
    y = st.chi2.cdf(x, 2)
    ax_l[0].plot(x, y, color='green',
    linewidth=2, label=r'$F(\chi^2_2)$')


    X = np.empty((len(x), 3))
    X[:,0] = np.ones_like(theta)*theta
    X[:,1] = np.ones_like(nu)*nu
    X[:,2] = np.linspace(0, low_edge[-1],len(x))
    
    cdf = tmodel.cdf(X)

    assert(len(cdf) == len(yc))

    res = cdf - yc
    
    ax_l[0].plot(X[:,2], cdf, label='$\hat{F}(\lambda)$', color='red')
    
    ax_l[1].set_ylabel(r'$f(\lambda)$', fontsize=ftsize)
    ax_l[1].hist(lambda_, bins=BINS, range=x_range,density=True,
    color=(0.8,0.8,0.9),
    histtype='stepfilled', edgecolor='black', label=r'$f(\lambda)$')
    
    #x = np.arange(0, xmax, 0.2)
    y = st.chi2.pdf(x, 2)
    ax_l[1].plot(x, y, color='green',
    linewidth=2, label=r'$f(\chi^2_2)$')
    
    ax_l[2].set_ylabel(r'$f(\lambda)= \partial \hat{F} / \partial \lambda$', fontsize=ftsize)
    ax_l[2].hist(lambda_, bins=BINS, range=x_range,density=True,
    color=(0.8,0.8,0.9),
    histtype='stepfilled', edgecolor='black', 
                 label=r'$f(\lambda)$'
                )


    pdf = tmodel.pdf(X)
    
    pdf_deriv = tmodel.numerical_deriv(X)
    ax_l[2].plot(X[:,2], pdf, label='$\partial \hat{F} / \partial \lambda$', color = 'r', linestyle='--' )
    ax_l[2].plot(X[:,2], pdf_deriv, label='numerical $\partial \hat{F} / \partial \lambda$', color='black', linestyle='--')
    
    ############################################################
    
    # annotate
    xwid = (xmax-xmin)/12
    ywid = (ymax-ymin)/12
    xpos = xmin + 3*xwid
    ypos = ymin + ywid*2
    for i in range(len(ax_l)):
        ax_l[i].set_xlim(x_range); ax_l[i].set_ylim(y_range)
        ax_l[i].set_xlabel(r'$\lambda \left(\mu,\nu \mid n, m \right)$',fontsize=ftsize-2)
        ax_l[i].text(xpos, ypos,
        r'$ \mu = %.2f, \nu = %.2f$' % (theta, nu),
        fontsize=ftsize-3)
        ax_l[i].legend(loc='upper right',fontsize=13)
        
    return x, res

# %%
#points=(theta,nu)
chi2_exp_size=400000

points_1 = (10, 4)

MLE=True
_, _ , lambda_1 = run_sim(theta=points_1[0], nu=points_1[1], MLE=MLE, lambda_size=chi2_exp_size)

fig, ax = plt.subplots(1,3, figsize=(10,5), sharey=True)

# plt.subplots_adjust(wspace=0.3)
# plot_one(lambda_1, points_1[0], points_1[1], ax)
x_res, y_res = plot_all(lambda_1, points_1[0], points_1[1], ax, MLE=MLE)

print(len(x_res), len(y_res))

fig.suptitle(r'MLE=%s; $N_{sample}$=%s' % \
             (  str(MLE), str(int(chi2_exp_size))), fontsize=25); 



SAVE=True
if SAVE:
    plt.savefig('../images/Wilk_agreement_MLE_%s_N_%s.pdf' % (str(MLE), str(chi2_exp_size) ), dpi=100)
plt.show()
# Out:
# [0.1686089  0.28863754 0.39319049 0.50274821 0.5781878  0.640083
#  0.69757351 0.73141429 0.74558396 0.81796017 0.84411354 0.87039549
#  0.8932737  0.90924356 0.92307537 0.93632981 0.94257252 0.94746131
#  0.96067036 0.96332528 0.96656262 0.97068493 0.97378108 0.97740922
#  0.98812219 0.99118556 0.99428423 0.9976552  0.99943523 1.        ] [ 0.          0.33333333  0.66666667  1.          1.33333333  1.66666667
#   2.          2.33333333  2.66666667  3.          3.33333333  3.66666667
#   4.          4.33333333  4.66666667  5.          5.33333333  5.66666667
#   6.          6.33333333  6.66666667  7.          7.33333333  7.66666667
#   8.          8.33333333  8.66666667  9.          9.33333333  9.66666667
#  10.        ]
# 30 30

# %%
#points=(theta,nu)
chi2_exp_size=400000

points_1 = (10, 4)

MLE=False
_, _ , lambda_1 = run_sim(theta=points_1[0], nu=points_1[1], MLE=MLE, lambda_size=chi2_exp_size)

fig, ax = plt.subplots(1,3, figsize=(10,5), sharey=True)

plt.subplots_adjust(wspace=0.3)
# plot_one(lambda_1, points_1[0], points_1[1], ax)
plot_all(lambda_1, points_1[0], points_1[1], ax, MLE=MLE)

fig.suptitle(r'MLE=%s; $N_{sample}$=%s' % \
             (  str(MLE), str(int(chi2_exp_size))), fontsize=25); 



SAVE=True
if SAVE:
    plt.savefig('../images/Wilk_agreement_MLE_%s_N_%s.pdf' % (str(MLE), str(chi2_exp_size) ))
plt.show()

# %% [markdown]
# # make 2 by 2 CDF panel for ALFFI

# %%
#points=(theta,nu)
chi2_exp_size=400000

points_1 = (10, 4)
points_2 = (6, 2)
points_3 = (12, 5)
points_4 = (9, 14)

points = [points_1, points_2, points_3, points_4]
MLE=False
_, _ , lambda_1 = run_sim(theta=points_1[0], nu=points_1[1], MLE=MLE, lambda_size=chi2_exp_size)
_, _ , lambda_2 = run_sim(theta=points_2[0], nu=points_2[1], MLE=MLE, lambda_size=chi2_exp_size)
_, _ , lambda_3 = run_sim(theta=points_3[0], nu=points_3[1], MLE=MLE, lambda_size=chi2_exp_size)
_, _ , lambda_4 = run_sim(theta=points_4[0], nu=points_4[1], MLE=MLE, lambda_size=chi2_exp_size)

lambda_l = [lambda_1, lambda_2, lambda_3, lambda_4]

# %%
fig, ax = plt.subplots(2,2,figsize=(10,10))
ax = ax.ravel()
BINS=30
tmodel = TrainedModel(trained_SiLU_model_nonMLE)

for ind, point in enumerate(points):
    
    theta, nu = point[0], point[1]
    df_single_point, eval_array = generate_theta_nu_single_point(theta=theta, nu=nu, N_points=300)
    lambda_ = eval_array[:,-1]
    ftsize = 16; xmin= 0; xmax= 10
    ymin= 0; ymax= 1
    x_range = (xmin, xmax)
    y_range = (ymin, ymax)
    
    ax[ind].set_ylabel(r'$F(\lambda)$', fontsize=ftsize)
    ax[ind].set_xlabel(r'$\lambda \left(\mu,\nu \mid n, m \right)$',fontsize=ftsize-2)
    # yc, low_edge, _ = ax[ind].hist(lambda_, bins=BINS, range=x_range,
    # color=(0.8,0.8,0.9),
    # color='powderblue',
    # density=True, cumulative=True,
    # histtype='stepfilled', edgecolor='black')
    
    # X = np.empty((len(lambda_), 3))
    # X[:,0] = np.ones_like(theta)*theta
    # X[:,1] = np.ones_like(nu)*nu
    # X[:,2] = np.linspace(0, 10,len(lambda_))
    
    
    # cdf = tmodel.cdf(X)
    
    cdf_ = tmodel.cdf(eval_array)
    
    ax[ind].plot(lambda_, cdf_, label='$\hat{F}_{ALFFI}$', color='red', linewidth=3)
    true_CDF = df_single_point['true_CDF'].to_numpy().flatten()
    ax[ind].plot(lambda_, true_CDF,  label=r'Empirical $F$',color='darkblue', linewidth=3, linestyle='--')
    # calculate conformal band
    true_cdf = yc
    
    Ncal = len(cdf_)
    
    xmin, xmax = 0, 10
    ymin, ymax = 0,1
    ax[ind].set_xlim(xmin,xmax)
    ax[ind].set_ylim(ymin,ymax)
    #annotate
    xwid = (xmax-xmin)/12
    ywid = (ymax-ymin)/12
    xpos = xmin + 3*xwid
    ypos = ymin + ywid*2
    ax[ind].text(xpos, ypos,
        r'$ \mu = %.2f, \nu = %.2f$' % (theta, nu),
        fontsize=ftsize)
    ax[ind].legend(loc='upper left',fontsize=ftsize-3)
    
plt.tight_layout()
plt.savefig('../images/ALFFI_CDF_panel.pdf')
plt.show()

# %%
fig, ax = plt.subplots(2,2,figsize=(10,10))
ax = ax.ravel()
BINS=30
tmodel = TrainedModel(trained_SiLU_model_nonMLE)

for ind, (lambda_, point) in enumerate(zip(lambda_l, points)):
    
    theta, nu = point[0], point[1]
    ftsize = 16; xmin= 0; xmax= 10
    ymin= 0; ymax= 1
    x_range = (xmin, xmax)
    y_range = (ymin, ymax)
    
    ax[ind].set_ylabel(r'$f(\lambda)$', fontsize=ftsize)
    ax[ind].set_xlabel(r'$\lambda \left(\mu,\nu \mid n, m \right)$',fontsize=ftsize-2)
    yc, low_edge, _ = ax[ind].hist(lambda_, bins=BINS, range=x_range,
    # color=(0.8,0.8,0.9),
                                   color='powderblue',
    density=True, 
    histtype='stepfilled', edgecolor='black', label=r'$f(\lambda)$')
    
    X = np.empty((len(lambda_), 3))
    X[:,0] = np.ones_like(theta)*theta
    X[:,1] = np.ones_like(nu)*nu
    X[:,2] = np.linspace(0, 10,len(lambda_))
    
    pdf = tmodel.pdf(X)
    ax[ind].plot(X[:,2], pdf, label='$\hat{f}_{ALFFI}$', color='red',linewidth=3)
    
        
    
    #annotate
    xwid = (xmax-xmin)/12
    ywid = (ymax-ymin)/12
    xpos = xmin + 3*xwid
    ypos = ymin + ywid*4
    ax[ind].text(xpos, ypos,
        r'$ \mu = %.2f, \nu = %.2f$' % (theta, nu),
        fontsize=ftsize)
    ax[ind].legend(loc='upper right',fontsize=ftsize-3)
    
plt.tight_layout()
plt.savefig('../images/ALFFI_PDF_panel.pdf')
plt.show()

# %% [markdown]
# # Make training data

# %%
def generate_X(theta, nu, N_points, MLE):
    N = st.poisson.rvs(theta+nu, size=N_points)
    M = st.poisson.rvs(nu, size=N_points)
    lambda_D = lambda_test_2d(N, M, theta, nu, MLE).flatten()
    X = np.empty((N_points, 3))
    X[:,0] = np.ones_like(theta)*theta
    X[:,1] = np.ones_like(nu)*nu
    X[:,2]  = lambda_D
    return X

def precision(arr):
    return [float(int(100000*x))/100000 for x in arr]

def cdf(lst, x):

    count = sum(1 for num in lst if num <= x)
    return count / len(lst)

# %%
def coarse_grain_lambda(lambda_, theta, nu, xbins=25, xmin=0, xmax=10):
    Y, edges = np.histogram(lambda_, bins=xbins, range=(xmin, xmax), density=True)
    h = edges[1]-edges[0]# bin width
    Y = np.cumsum(Y) * h# are (CDF_)
    x = (edges[1:]+edges[:-1])/2#bin centers
    X = np.empty((len(x), 3))
    X[:,0] = np.ones_like(theta)*theta
    X[:,1] = np.ones_like(nu)*nu
    X[:,2] = np.linspace(x[0], x[-1],len(x))
    return Y, X

# %%
# t = 10
# n = 4
# X = generate_X(theta=t, nu=n, N_points=1000, MLE=False)
# lambda_ = X[:,2].flatten()
# Y, X = coarse_grain_lambda(lambda_, t, n)
# Y

# %%
tmodel = TrainedModel(trained_SiLU_model_nonMLE)

def generate_theta_nu_single_point_coarse_grain(tmodel, theta, nu, N_points=5000, xbins=25, xmin=0, xmax=10):
    """non MLE evaluation data for the correction function at a single theta, nu point"""


    X = generate_X(theta=theta, nu=nu, N_points=N_points, MLE=False)
    lambda_ = X[:,2].flatten()
    lambda_ = precision(lambda_)
    Y, X = coarse_grain_lambda(lambda_, theta, nu, xbins, xmin, xmax)
    a = tmodel.cdf(X)
    assert(len(a) == len(Y))
    
    res = a - Y
    eval_list=[]
    d = []
    for l, r in zip(lambda_, res):
        d.append([theta, nu, l, r])
        eval_list.append([theta, nu, l])
    eval_array = np.array(eval_list)
    return d, eval_array

# %%
d, eval_array = generate_theta_nu_single_point_coarse_grain(tmodel= tmodel, theta=10, nu=5)
print(eval_array.shape)
# Out:
# (25, 3)

# %%
Npoints = 200000
theta_random = np.random.uniform(0, 20, Npoints)
nu_random = np.random.uniform(0, 20, Npoints)

tdata = []
for ii, (t, n) in enumerate(zip(theta_random, nu_random)):
    if ii % 100 == 0: print(f'\r{ii:10d}', end='')
    d, _ = generate_theta_nu_single_point_coarse_grain(tmodel, t, n)
    tdata += d

np.random.shuffle(tdata)
print(tdata[:5])
# Out:
#     199900[[18.92618662059423, 10.578512226633645, 1.70831, -0.02723733419019647], [7.709451369777378, 13.136477222068839, 1.12572, -0.00811654967878328], [10.433744529050193, 2.508377445063479, 1.85069, -0.015683058187389687], [14.730780636274346, 15.764857960016947, 5.04921, -0.08403989972845372], [19.112963860866515, 12.446361959538887, 1.5582, -0.138898271721539]]

# %%
dfout = pd.DataFrame(tdata, columns=['theta', 'nu', 'lambda', 'residual'])
dfout[:5]
# Out:
#        theta         nu   lambda  residual
# 0  18.926187  10.578512  1.70831 -0.027237
# 1   7.709451  13.136477  1.12572 -0.008117
# 2  10.433745   2.508377  1.85069 -0.015683
# 3  14.730781  15.764858  5.04921 -0.084040
# 4  19.112964  12.446362  1.55820 -0.138898

# %%
dfout.to_csv('../data/On_Off_Coarse_Grained_TrainingData.csv', index=False)

# %%
dfout = pd.read_csv('../data/On_Off_Coarse_Grained_TrainingData.csv')
dfout
# Out:
#              theta         nu   lambda  residual
# 0        18.926187  10.578512  1.70831 -0.027237
# 1         7.709451  13.136477  1.12572 -0.008117
# 2        10.433745   2.508377  1.85069 -0.015683
# 3        14.730781  15.764858  5.04921 -0.084040
# 4        19.112964  12.446362  1.55820 -0.138898
# ...            ...        ...      ...       ...
# 4999995   0.770305   8.155709  1.12661 -0.001716
# 4999996   7.478852  13.754175  0.73563 -0.140785
# 4999997  11.100915   4.004999  7.27642 -0.005274
# 4999998  15.375566  10.106275  0.88333 -0.005229
# 4999999  17.826483   6.193043  0.87890 -0.049828
#
# [5000000 rows x 4 columns]

# %%
def generate_theta_nu_single_point(theta, nu, N_points=10000):
    """non MLE evaluation data for the correction function at a single theta, nu point"""
    data = pd.DataFrame({'theta':[theta], 'nu':[nu]})
    tmodel = TrainedModel(trained_SiLU_model_nonMLE)

    
    for rowind, row in data.iterrows():
        X = generate_X(theta=row['theta'], nu=row['nu'], N_points=N_points, MLE=False)
        lambda_ = X[:,2].flatten()
        lambda_ = precision(lambda_)
        
        data.loc[rowind, 'lambda'] =str(lambda_)
        
        true_CDF_l = []
        for lambda_val in lambda_:
            true_CDF_l.append(cdf(lambda_, lambda_val))
            
        a = tmodel.cdf(X)

        
        p  = np.linspace(0,1,N_points)

        q = np.quantile(a, p)

        q = precision(q)
        data.loc[rowind, 'q'] = str(q)
        
        a = precision(a)
        data.loc[rowind, 'pred_CDF'] =str(a)
        
        delta_C = p-q
        delta_C = precision(delta_C)
        data.loc[rowind, 'delta_C'] = str(delta_C)
    

    theta_l = []
    nu_l= []
    q_l = []
    delta_C_l = []
    lambda_l = []
    pred_CDF_l = []
    

    for row_ind, row in data.iterrows():
        lambda_ = eval(row['lambda'])
        lambda_l.append(lambda_)
        
        
        q=eval(row['q'])
        q_l.append(q)

        pred_CDF = eval(row['pred_CDF'])
        pred_CDF_l.append(pred_CDF)
            
        theta_r = np.full_like(q, row['theta'])
        theta_l.append(theta_r)

        nu_r = np.full_like(q, row['nu'])
        nu_l.append(nu_r)


        delta_C = eval(row['delta_C'])
        delta_C_l.append(delta_C)

    theta_l=np.array(theta_l).flatten()
    nu_l=np.array(nu_l).flatten()
    q_l=np.array(q_l).flatten()
    delta_C_l=np.array(delta_C_l).flatten()
    lambda_l=np.array(lambda_l).flatten()
    pred_CDF_l=np.array(pred_CDF_l).flatten()
    true_CDF_l=np.array(true_CDF_l).flatten()
    delta_r = pred_CDF_l-true_CDF_l
    
    
    # y = delta_C_l - min(delta_C_l)
    # y = y/np.std(y)

    data_flat=pd.DataFrame({'theta': theta_l,
                       'nu': nu_l,
                       'q': q_l,
                        'lambda':lambda_l,
                       'delta_C': delta_C_l,
                        'pred_CDF': pred_CDF_l,
                            'true_CDF':true_CDF_l,
                            'delta_r':delta_r,
                           # 'y':y
                           })
    
    data_flat=data_flat.sort_values(by='lambda')
    # data_flat=data_flat.sort_values(by='q')
    # eval_array = data_flat[['theta', 'nu', 'lambda', 'true_CDF']].to_numpy()
    eval_array = data_flat[['theta', 'nu', 'lambda']].to_numpy()
    return data_flat, eval_array

# %%
df_single_point, _ = generate_theta_nu_single_point(theta=19, nu=5, N_points=10000)
df_single_point
# Out:
#       theta   nu        q   lambda  delta_C  pred_CDF  true_CDF  delta_r
# 0      19.0  5.0  0.04055  1.16389 -0.04055   0.39220    0.4485 -0.05630
# 88     19.0  5.0  0.04055  1.10654 -0.03174   0.37679    0.4341 -0.05731
# 87     19.0  5.0  0.04055  0.38635 -0.03184   0.11650    0.2038 -0.08730
# 86     19.0  5.0  0.04055  3.16350 -0.03194   0.75692    0.7871 -0.03018
# 85     19.0  5.0  0.04055  1.10654 -0.03204   0.37679    0.4341 -0.05731
# ...     ...  ...      ...      ...      ...       ...       ...      ...
# 9997   19.0  5.0  0.99999  0.57954 -0.00019   0.21948    0.2470 -0.02752
# 9998   19.0  5.0  0.99999  0.57513 -0.00009   0.21767    0.2367 -0.01903
# 9995   19.0  5.0  0.99999  2.37709 -0.00039   0.62124    0.6801 -0.05886
# 9996   19.0  5.0  0.99999  5.61870 -0.00029   0.91368    0.9384 -0.02472
# 9999   19.0  5.0  0.99999  0.22895  0.00000   0.07520    0.1067 -0.03150
#
# [10000 rows x 8 columns]

# %%
df_single_point

# %%
def plot_q_deltar_points(nrows, ncols, scatter = False):
    fig, ax = plt.subplots(nrows,ncols, figsize=(20,20))
    ax = ax.ravel()
    theta_nu_l = [(theta, nu) for theta in np.linspace(5,5.2, nrows) for nu in np.linspace(5,5.2, ncols)]
    for ind, (theta, nu) in enumerate(theta_nu_l):
        data_flat_eval, eval_array =generate_theta_nu_single_point(theta=theta, nu=nu, N_points=101)
        
        # delta_r = data_flat_eval['pred_CDF'] - data_flat_eval['true_CDF']
        delta_r=data_flat_eval['delta_r']
        if scatter:
            ax[ind].scatter(data_flat_eval['lambda'],delta_r, label=r'$\Delta r = F_{pred}-F_{true}$')
        else:
            ax[ind].plot(data_flat_eval['lambda'],delta_r, label=r'$\Delta r = \hat{F}-F $', linewidth=3)
        xmin, xmax = 0, data_flat_eval['lambda'].max()
        ymin, ymax = -0.1, 0.1
        xwid = (xmax-xmin)/12
        ywid = (ymax-ymin)/12
        xpos = xmin + 6*xwid
        ypos = ymin #+ ywid
        
        
        ax[ind].text(xpos, ypos, r'$ \mu = %.2f, \nu = %.2f$' % (theta, nu), fontsize=25)
        ax[ind].set_ylim(-0.2,0.125)
        ax[ind].set_xlabel(r'$\lambda$')
        ax[ind].set_ylabel(r'$\Delta r$', fontsize=25)
        ax[ind].plot([0,xmax],[0,0], linestyle='dashed', color='r')
        ax[ind].legend(fontsize=25)
    plt.tight_layout()
    plt.savefig('../images/on_off_delta_r.pdf')
    plt.show()

# %% [markdown]
# # observe that $\Delta r$ is a smooth function of the parameters $(\mu,\nu)$

# %%
plot_q_deltar_points(nrows=2, ncols=2)

# %%
def plot_q_deltac_points(nrows, ncols, scatter = False):
    fig, ax = plt.subplots(nrows,ncols, figsize=(20,20))
    ax = ax.ravel()
    theta_nu_l = [(theta, nu) for theta in np.linspace(5,5.2, nrows) for nu in np.linspace(5,5.2, ncols)]
    for ind, (theta, nu) in enumerate(theta_nu_l):
        data_flat_eval, eval_array =generate_theta_nu_single_point(theta=theta, nu=nu, N_points=101)
        
        # delta_r = data_flat_eval['pred_CDF'] - data_flat_eval['true_CDF']
        delta_C=data_flat_eval['delta_C']

        ax[ind].plot(data_flat_eval['q'],delta_C, label=r'$\Delta C = \hat{q}-p $', linewidth=3)
        xmin, xmax = 0, data_flat_eval['q'].max()
        ymin, ymax = -0.1, 0.1
        xwid = (xmax-xmin)/12
        ywid = (ymax-ymin)/12
        xpos = xmin + 6*xwid
        ypos = ymin + 3*ywid
        
        ax[ind].set_xlim(xmin, xmax)
        ax[ind].text(xpos, ypos, r'$ \mu = %.2f, \nu = %.2f$' % (theta, nu), fontsize=25)
        ax[ind].set_ylim(-0.1,0.2)
        ax[ind].set_xlabel(r'$\hat{q}$', fontsize=25)
        ax[ind].set_ylabel(r'$\Delta C$', fontsize=25)
        ax[ind].plot([0,xmax],[0,0], linestyle='dashed', color='r')
        ax[ind].legend(fontsize=25)
    plt.tight_layout()
    plt.savefig('../images/on_off_delta_C.pdf')
    plt.show()

# %%
plot_q_deltac_points(nrows=2, ncols=2, scatter = False)

# %%
def generate_theta_nu_all_points(N_points):
    """non MLE evaluation data for the correction function at a single theta, nu point"""
    thetamin, thetamax  =0,20
    numin, numax  =0,20
    theta = st.uniform.rvs(thetamin, thetamax, size=N_points)
    nu = st.uniform.rvs(numin, numax, size=N_points)
    data = pd.DataFrame({'theta':theta, 'nu':nu})

    tmodel = TrainedModel(trained_SiLU_model_nonMLE)

    
    for rowind, row in data.iterrows():
        X = generate_X(theta=row['theta'], nu=row['nu'], N_points=100, MLE=False)
        lambda_ = X[:,2].flatten()
        lambda_ = precision(lambda_)
        data.loc[rowind, 'lambda'] =str(lambda_)
        
        
        true_CDF_l = []
        for lambda_val in lambda_:
            true_CDF_l.append(cdf(lambda_, lambda_val))
        true_CDF_l = precision(true_CDF_l)
        data.loc[rowind,'true_CDF'] = str(true_CDF_l)
        
        
        a = tmodel.cdf(X)
        a = precision(a)
        data.loc[rowind, 'pred_CDF'] =str(a)
        

    

    theta_l = []
    nu_l= []
    lambda_l = []
    pred_CDF_l = []
    true_CDF_l = []
    

    for row_ind, row in data.iterrows():
        lambda_ = eval(row['lambda'])
        lambda_l.append(lambda_)
        
        

        pred_CDF = eval(row['pred_CDF'])
        pred_CDF_l.append(pred_CDF)
        
        true_CDF = eval(row['true_CDF'])
        true_CDF_l.append(true_CDF)
        
        
        theta_r = np.full_like(lambda_, row['theta'])
        theta_l.append(theta_r)

        nu_r = np.full_like(lambda_, row['nu'])
        nu_l.append(nu_r)


    theta_l=np.array(theta_l).flatten()
    nu_l=np.array(nu_l).flatten()
    lambda_l=np.array(lambda_l).flatten()
    pred_CDF_l=np.array(pred_CDF_l).flatten()
    true_CDF_l=np.array(true_CDF_l).flatten()
    delta_r = pred_CDF_l-true_CDF_l
    
    
    # y = delta_C_l - min(delta_C_l)
    # y = y/np.std(y)

    data_flat=pd.DataFrame({'theta': theta_l,
                       'nu': nu_l,
                        'lambda':lambda_l,
                        'pred_CDF': pred_CDF_l,
                            'true_CDF':true_CDF_l,
                            'delta_r':delta_r,
                           # 'y':y
                           })
    
    # eval_array = data_flat[['theta', 'nu', 'lambda', 'true_CDF']].to_numpy()
    eval_array = data_flat[['theta', 'nu', 'lambda']].to_numpy()
    return data_flat, eval_array

# %%
df_all_points,_ =generate_theta_nu_all_points(N_points=100000)
df_all_points
# Out:
#             theta         nu   lambda  pred_CDF  true_CDF  delta_r
# 0        3.663042   2.367801  0.20835   0.08276      0.12 -0.03724
# 1        3.663042   2.367801  0.73806   0.25862      0.25  0.00862
# 2        3.663042   2.367801  4.88361   0.90673      0.85  0.05673
# 3        3.663042   2.367801  0.73806   0.25862      0.25  0.00862
# 4        3.663042   2.367801  3.34421   0.78731      0.74  0.04731
# ...           ...        ...      ...       ...       ...      ...
# 9999995  1.189176  18.824614  1.06626   0.46554      0.55 -0.08446
# 9999996  1.189176  18.824614  0.34353   0.16255      0.18 -0.01745
# 9999997  1.189176  18.824614  3.55421   0.86393      0.92 -0.05607
# 9999998  1.189176  18.824614  4.18490   0.90262      0.96 -0.05738
# 9999999  1.189176  18.824614  4.32135   0.91094      0.97 -0.05906
#
# [10000000 rows x 6 columns]

# %%
df_all_points.to_csv('../data/df_all_points.csv', index=False)

# %%
df_all_points = pd.read_csv('../data/df_all_points.csv')

# %% [markdown]
# # Train NN to fit residuals ($\Delta r$) or True CDF

# %%
def split_t_x(df, target, source):
    # change from pandas dataframe format to a numpy 
    # array of the specified types
    t = np.array(df[target])
    x = np.array(df[source])
    return t, x

def getwholedata_delta_r():
    """ Get train test split arrays"""
    
    data = df_all_points
    COARSE_GRAINED=False
    if COARSE_GRAINED:
        data = dfout
        
    train_data, test_data = train_test_split(data, test_size=0.1)
    #split the train data (0.8 of whole set) again into 0.8*0.8=0.64 of whole set
    

    train_data = train_data.reset_index(drop=True)
    test_data  = test_data.reset_index(drop=True)

    target='true_CDF'
    # target='y'
    # source = ['theta','nu','theta_hat','N','M']

    # source = ['theta', 'nu', 'lambda', 'true_CDF']
    source = ['theta', 'nu', 'lambda']

    train_t, train_x = split_t_x(train_data, target=target, source=source)
    test_t,  test_x  = split_t_x(test_data,  target=target, source=source)
    print('train_t shape = ', train_t.shape, '\n')
    print('train_x shape = ', train_x.shape, '\n')
    
    # if valid:
        #if you want to also make a validation data set
    train_data, valid_data = train_test_split(train_data, test_size=0.015)
    valid_data = valid_data.reset_index(drop=True)
    valid_t, valid_x = split_t_x(valid_data, target=target, source=source)

        
    return train_t, train_x, test_t,  test_x, valid_t, valid_x

# %%
train_t, train_x, test_t,  test_x, valid_t, valid_x = getwholedata_delta_r()
N_Features = train_x.shape[1]
# Out:
# train_t shape =  (9000000,)
#
# train_x shape =  (9000000, 3)

# %%
def get_features_training_batch(x, t, batch_size):
    # the numpy function choice(length, number)
    # selects at random "batch_size" integers from 
    # the range [0, length-1] corresponding to the
    # row indices.
    rows    = np.random.choice(len(x), batch_size)
    batch_x = x[rows]
    batch_t = t[rows]
    # batch_x.T[-1] = np.random.uniform(0, 1, batch_size)
    return (batch_x, batch_t)

# %%
class SaveModelCheckpoint:
    """Continuous model-checkpointing class. Updates the latest checkpoint of an object based o validation loss each time its called. 
    """
    def __init__(self, best_valid_loss=np.inf):
        """Initiate an instance of the class based on filename and best_valid_loss/

        Args:
            best_valid_loss (float, optional): Best possible validation loss of a checkpoint object. Defaults to np.inf.
        """
        self.best_valid_loss = best_valid_loss

    def __call__(self, model, current_valid_loss, PARAMS, pth_string):
        """When an object of the calss is called, its validation loss gets updated and the model based 
        on the latest validation loss is saved.

        Args:
            model: utils.RegularizedRegressionModel object.
            current_valid_loss (float): current (latest) validation loss of this model during the training process.
            filename_model (str): filename in which the latest model will be saved. Can be a relative or local path. 
        """
        if current_valid_loss < self.best_valid_loss:
            # update the best loss
            self.best_valid_loss = current_valid_loss
            # filename_model='Trained_IQNx4_%s_%sK_iter.dict' % (target, str(int(n_iterations/1000)) )
            # filename_model = "Trained_IQNx4_%s_TUNED_2lin_with_noise.dict" % target

            # note that n_iterations is the total n_iterations, we dont want to save a million files for each iteration
            save_model(model, PARAMS, pth_string)
            print(
                f"\nCurrent valid loss: {current_valid_loss};  saved better model in models/{pth_string}"
            )
            # save using .pth object which if a dictionary of dicionaries, so that I can have PARAMS saved in the same file

# %%
from torch.autograd import Variable

class SinActivation(torch.nn.Module):
    def __init__(self):
        super(SinActivation, self).__init__()
        
    def forward(self, x):
        return torch.sin(x)
    
    
class True_CDF_Model(nn.Module):
    #inherit from the super class
    def __init__(self, nfeatures, ntargets, nlayers, hidden_size, dropout):
        super().__init__()
        layers = []
        for _ in range(nlayers):
            if len(layers) ==0:
                #inital layer has to have size of input features as its input layer
                #its output layer can have any size but it must match the size of the input layer of the next linear layer
                #here we choose its output layer as the hidden size (fully connected)
                layer = nn.Linear(nfeatures, hidden_size)
                # torch.nn.init.xavier_uniform_(layer.weight, gain=60)
                torch.nn.init.xavier_normal_(layer.weight, 
                                             # gain=60
                                            )
                layers.append(layer)
                #batch normalization
                layers.append(nn.BatchNorm1d(hidden_size))
                #Dropout seems to worsen model performance
                # layers.append(nn.Dropout(dropout))
                #ReLU activation 
                layers.append(nn.SiLU())
                # layers.append(SinActivation())
                # layers.append(GroupSort(num_groups=1))
            else:
                #if this is not the first layer (we dont have layers)
                layer = nn.Linear(hidden_size, hidden_size)
                # torch.nn.init.xavier_uniform_(layer.weight, gain=60)
                torch.nn.init.xavier_normal_(layer.weight, 
                                             # gain=60
                                            )
                layers.append(layer)
                # layers.append(nn.BatchNorm1d(hidden_size))
                #Dropout seems to worsen model performance
                # layers.append(nn.Dropout(dropout))
                layers.append(nn.SiLU())
                # layers.append(nn.Tanh())
                # layers.append(nn.ReLU())
                # layers.append(SinActivation())
                
                #output layer:
        output_layer = nn.Linear(hidden_size, ntargets)
        torch.nn.init.xavier_uniform_(output_layer.weight)
        layers.append(output_layer) 

        # ONLY IF ITS A CLASSIFICATION, ADD SIGMOID
        # layers.append(nn.Sigmoid())
            #we have defined sequential model using the layers in oulist 
        self.model = nn.Sequential(*layers)

    
    def forward(self, x):
        return self.model(x)
    
def xavier_init_lstm(lstm):
    for name, param in lstm.named_parameters():
        if 'weight_ih' in name:
            nn.init.xavier_uniform_(param.data, gain=60)
        elif 'weight_hh' in name:
            nn.init.orthogonal_(param.data)
        elif 'bias' in name:
            nn.init.constant_(param.data, 0)
            
            
class Delta_r_Model_LSTM(nn.Module):
    #inherit from the super class
    def __init__(self, nfeatures, 
                 ntargets, nlayers, hidden_size, dropout):
        super(Delta_r_Model_LSTM, self).__init__()
        self.hidden_size=hidden_size
        self.nlayers = nlayers
        
        self.lstm = nn.LSTM(nfeatures, hidden_size, nlayers, batch_first=True)
        xavier_init_lstm(self.lstm)

        self.batchnorm = nn.BatchNorm1d(hidden_size)
#         self.layer_1 = nn.Linear(hidden_size, hidden_size)
        self.relu = nn.ReLU()
        self.sin = SinActivation()
        
        self.output_layer = nn.Linear(hidden_size, ntargets)
        torch.nn.init.xavier_uniform_(self.output_layer.weight)
        
    def forward(self, x):
        hidden_states = torch.zeros(self.nlayers, x.size(0), self.hidden_size).to(device)
        cell_states = torch.zeros(self.nlayers, x.size(0), self.hidden_size).to(device)
        
        out, (hn,cn) = self.lstm(x, (hidden_states, cell_states))
#         hn =hn.view(-1, self.hidden_size)
#         hn = hn[:, -1, 3]
        batch_norm=False
        if batch_norm==True:
            out = out.permute(0,2,1)
            out = self.batchnorm(out)
            out = out.permute(0,2,1)
        out = self.sin(out)
        out = self.output_layer(out[:, -1, :])
#         out = SinActivation(hn)
#         out = self.relu(hn)

#         out = self.layer_1(out)
#         out = self.relu(out)
#         out = self.output_layer(out)
        return out

# %%
def RMS(v):
    return (torch.mean(v**2)) ** 0.5

def average_quadratic_loss(f, t, x):
    # f and t must be of the same shape

    # inv = torch.where(t !=0, 1/torch.abs(t), 1)
    
    # inv_RMS = torch.where(t !=0, 1/RMS(t), 1)
    
    return  torch.mean(  (f - t)**2)

def huber_loss(f, t, x):
    delta= torch.Tensor([0.1])
    error = f - t
    abs_error = torch.abs(error)
    quadratic = torch.minimum(abs_error, delta)
    linear = (abs_error - quadratic)
    return torch.mean(0.5 * quadratic ** 2 + delta * linear)

def kl_divergence_loss(q, p, x):
    criterion = torch.nn.KLDivLoss(reduction='batchmean')
    loss = criterion(torch.log(p), q)
    return loss


def validate(model, avloss, inputs, targets):
    # make sure we set evaluation mode so that any training specific
    # operations are disabled.
    model.eval() # evaluation mode
    
    with torch.no_grad(): # no need to compute gradients wrt. x and t
        x = torch.from_numpy(inputs).float().to(device)
        t = torch.from_numpy(targets).float().to(device)
        # remember to reshape!
        o = model(x).reshape(t.shape)
    return avloss(o, t, x)


def train_true_CDF(model, optimizer, avloss,
          batch_size, 
          n_iterations, traces, 
          step, window,
                  PARAMS,
                  pth_string):
    
    # to keep track of average losses
    xx, yy_t, yy_v, yy_v_avg = traces
    
    model = model.to(device)
    

    train_t, train_x, test_t,  test_x, _, _ = getwholedata_delta_r()

        
    model_checkpoint = SaveModelCheckpoint()
    
    n = len(test_x)
    print('Iteration vs average loss')
    print("%10s\t%10s\t%10s" % \
          ('iteration', 'train-set', 'valid-set'))
    
    # training_set_features, training_set_targets, evaluation_set_features, evaluation_set_targets = get_data_sets(simulate_data=False, batchsize=batch_size)
    
    for ii in range(n_iterations):

        # set mode to training so that training specific 
        # operations such as dropout are enabled.

        
        model.train()
        
        # get a random sample (a batch) of data (as numpy arrays)
        
        #Harrison-like Loader
        batch_x, batch_t = get_features_training_batch(train_x, train_t, batch_size)
        
        #Or Ali's Loader
        # batch_x, batch_t = next(training_set_features()), next(training_set_targets())
        # batch_x_eval, batch_t_eval = next(evaluation_set_features()), next(evaluation_set_targets())

        with torch.no_grad(): # no need to compute gradients 
            # wrt. x and t
            x = torch.from_numpy(batch_x).float().to(device)
            t = torch.from_numpy(batch_t).float().to(device)    


        outputs = model(x).reshape(t.shape)
   
        # compute a noisy approximation to the average loss
        empirical_risk = avloss(outputs, t, x)
        
        # use automatic differentiation to compute a 
        # noisy approximation of the local gradient
        optimizer.zero_grad()       # clear previous gradients
        empirical_risk.backward()   # compute gradients
        
        # finally, advance one step in the direction of steepest 
        # descent, using the noisy local gradient. 
        optimizer.step()            # move one step
        
        if ii % step == 0:
            
            
            #using Harrison-like loader
            acc_t = validate(model, avloss, train_x[:n], train_t[:n]) 
            acc_v = validate(model, avloss, test_x[:n], test_t[:n])
            
            model_checkpoint(model=model, current_valid_loss=acc_v, PARAMS=PARAMS, pth_string=pth_string)

            #using Ali's loader
            # acc_t = validate(model, avloss, batch_x, batch_t) 
            # acc_v = validate(model, avloss, batch_x_eval, batch_t_eval)
            

            yy_t.append(acc_t)
            yy_v.append(acc_v)
            
            # compute running average for validation data
            len_yy_v = len(yy_v)
            if   len_yy_v < window:
                yy_v_avg.append( yy_v[-1] )
            elif len_yy_v == window:
                yy_v_avg.append( sum(yy_v) / window )
            else:
                acc_v_avg  = yy_v_avg[-1] * window
                acc_v_avg += yy_v[-1] - yy_v[-window-1]
                yy_v_avg.append(acc_v_avg / window)
                        
            if len(xx) < 1:
                xx.append(0)
                print("%10d\t%10.6f\t%10.6f" % \
                      (xx[-1], yy_t[-1], yy_v[-1]))
            else:
                xx.append(xx[-1] + step)
                    
                print("\r%10d\t%10.6f\t%10.6f\t%10.6f" % \
                          (xx[-1], yy_t[-1], yy_v[-1], yy_v_avg[-1]), 
                      end='')
            
    print()      
    return (xx, yy_t, yy_v, yy_v_avg)

# %%
def load_untrained_true_CDF_model(PARAMS):
    """Load an untrained model (with weights initiatted) according to model paramateters in the 
    PARAMS dictionary

    Args:
        PARAMS (dict): dictionary of model/training parameters: i.e. hyperparameters and training parameters.

    Returns:
        utils.RegularizedRegressionModel object
    """
    model = True_CDF_Model(
        nfeatures=PARAMS['NFEATURES'],
        ntargets=1,
        nlayers=PARAMS["n_layers"],
        hidden_size=PARAMS["hidden_size"],
        dropout=PARAMS["dropout"],
        # activation=PARAMS["activation"]
    )
    # model.apply(initialize_weights)
    print('INITIATED UNTRAINED MODEL:',
          # model
         )
    # print(model)
    return model

# %%
True_CDF_model_PARAMS = {
"n_layers": int(6),
"hidden_size": int(12),
"dropout": float(0.13),
"NFEATURES":int(N_Features),
"activation": "SiLU",
'optimizer_name':'NAdam',
    # 'optimizer_name':'RMSprop',
'starting_learning_rate':float(0.00003),
'momentum':float(0.9),
'batch_size':int(60),
'n_iterations': int(1e6),
'traces_step':int(100),
'L2':float(0.1),
'MLE':False,
'with_lambda_D':True,
'pth_string':'True_CDF_model_SILU.pth'
}

# %%
true_CDF_model = load_untrained_true_CDF_model(True_CDF_model_PARAMS)

BATCHSIZE=True_CDF_model_PARAMS["batch_size"]
traces_SiLU = ([], [], [], [])
traces_step = 200
optimizer_name=True_CDF_model_PARAMS["optimizer_name"]


optimizer_delta_r = getattr(torch.optim, str(optimizer_name))(true_CDF_model.parameters(), 
                                                           lr=True_CDF_model_PARAMS["starting_learning_rate"])

traces_SiLU = train_true_CDF(model=true_CDF_model, 
              optimizer=optimizer_delta_r, 
              avloss=average_quadratic_loss,
                            # avloss=huber_loss,
              batch_size=BATCHSIZE, 
              n_iterations=True_CDF_model_PARAMS["n_iterations"], 
              traces=traces_SiLU, 
              step=traces_step, 
              window=200,
                           PARAMS=True_CDF_model_PARAMS,
                           pth_string=True_CDF_model_PARAMS['pth_string'])
# Out:
# INITIATED UNTRAINED MODEL:
# train_t shape =  (9000000,)
#
# train_x shape =  (9000000, 3)
#
# Iteration vs average loss
#  iteration	 train-set	 valid-set
# saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.36755993962287903;  saved better model in models/True_CDF_model_SILU.pth
#          0	  0.367489	  0.367560
# saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.35305255651474;  saved better model in models/True_CDF_model_SILU.pth
#        200	  0.352987	  0.353053	  0.353053saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.3090053200721741;  saved better model in models/True_CDF_model_SILU.pth
#        400	  0.308941	  0.309005	  0.309005saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.2658732533454895;  saved better model in models/True_CDF_model_SILU.pth
#        600	  0.265808	  0.265873	  0.265873saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.22741080820560455;  saved better model in models/True_CDF_model_SILU.pth
#        800	  0.227344	  0.227411	  0.227411saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.18767966330051422;  saved better model in models/True_CDF_model_SILU.pth
#       1000	  0.187614	  0.187680	  0.187680saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.15066365897655487;  saved better model in models/True_CDF_model_SILU.pth
#       1200	  0.150603	  0.150664	  0.150664saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.12041829526424408;  saved better model in models/True_CDF_model_SILU.pth
#       1400	  0.120356	  0.120418	  0.120418saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.09526677429676056;  saved better model in models/True_CDF_model_SILU.pth
#       1600	  0.095208	  0.095267	  0.095267saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.07450603693723679;  saved better model in models/True_CDF_model_SILU.pth
#       1800	  0.074460	  0.074506	  0.074506saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.06407967954874039;  saved better model in models/True_CDF_model_SILU.pth
#       2000	  0.064041	  0.064080	  0.064080saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.056155696511268616;  saved better model in models/True_CDF_model_SILU.pth
#       2200	  0.056127	  0.056156	  0.056156saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.049891192466020584;  saved better model in models/True_CDF_model_SILU.pth
#       2400	  0.049871	  0.049891	  0.049891saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.0465066097676754;  saved better model in models/True_CDF_model_SILU.pth
#       2600	  0.046491	  0.046507	  0.046507saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.043571650981903076;  saved better model in models/True_CDF_model_SILU.pth
#       2800	  0.043563	  0.043572	  0.043572saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.04028607904911041;  saved better model in models/True_CDF_model_SILU.pth
#       3000	  0.040280	  0.040286	  0.040286saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.03554671257734299;  saved better model in models/True_CDF_model_SILU.pth
#       3200	  0.035547	  0.035547	  0.035547saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.03259360417723656;  saved better model in models/True_CDF_model_SILU.pth
#       3400	  0.032594	  0.032594	  0.032594saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.028702499344944954;  saved better model in models/True_CDF_model_SILU.pth
#       3600	  0.028706	  0.028702	  0.028702saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.025322461500763893;  saved better model in models/True_CDF_model_SILU.pth
#       3800	  0.025329	  0.025322	  0.025322saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.020376872271299362;  saved better model in models/True_CDF_model_SILU.pth
#       4000	  0.020388	  0.020377	  0.020377saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.017629211768507957;  saved better model in models/True_CDF_model_SILU.pth
#       4200	  0.017645	  0.017629	  0.017629saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.01449513714760542;  saved better model in models/True_CDF_model_SILU.pth
#       4400	  0.014516	  0.014495	  0.014495saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.014188242144882679;  saved better model in models/True_CDF_model_SILU.pth
#       4600	  0.014214	  0.014188	  0.014188saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.011532451026141644;  saved better model in models/True_CDF_model_SILU.pth
#       4800	  0.011554	  0.011532	  0.011532saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.009731372818350792;  saved better model in models/True_CDF_model_SILU.pth
#       5000	  0.009756	  0.009731	  0.009731saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.009316102601587772;  saved better model in models/True_CDF_model_SILU.pth
#       5200	  0.009347	  0.009316	  0.009316saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.008075913414359093;  saved better model in models/True_CDF_model_SILU.pth
#       5400	  0.008106	  0.008076	  0.008076saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.007324392907321453;  saved better model in models/True_CDF_model_SILU.pth
#       5600	  0.007353	  0.007324	  0.007324saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.006958661135286093;  saved better model in models/True_CDF_model_SILU.pth
#       5800	  0.006990	  0.006959	  0.006959saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.0059681301936507225;  saved better model in models/True_CDF_model_SILU.pth
#       6000	  0.005996	  0.005968	  0.005968saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.005719849839806557;  saved better model in models/True_CDF_model_SILU.pth
#       6400	  0.005832	  0.005805	  0.005805saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.005540804471820593;  saved better model in models/True_CDF_model_SILU.pth
#       6600	  0.005566	  0.005541	  0.005541saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.005272285547107458;  saved better model in models/True_CDF_model_SILU.pth
#       6800	  0.005297	  0.005272	  0.005272saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.004883109591901302;  saved better model in models/True_CDF_model_SILU.pth
#       7200	  0.004917	  0.004896	  0.004896saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.0048309131525456905;  saved better model in models/True_CDF_model_SILU.pth
#       7400	  0.004853	  0.004831	  0.004831saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.004500991199165583;  saved better model in models/True_CDF_model_SILU.pth
#       7800	  0.004557	  0.004537	  0.004537saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.004382249433547258;  saved better model in models/True_CDF_model_SILU.pth
#       8200	  0.004428	  0.004411	  0.004411saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.004226070363074541;  saved better model in models/True_CDF_model_SILU.pth
#       8600	  0.004361	  0.004345	  0.004345saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.004096522927284241;  saved better model in models/True_CDF_model_SILU.pth
#       8800	  0.004116	  0.004097	  0.004097saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.003975622821599245;  saved better model in models/True_CDF_model_SILU.pth
#       9200	  0.004371	  0.004347	  0.004347saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.0038660855498164892;  saved better model in models/True_CDF_model_SILU.pth
#      10400	  0.003899	  0.003886	  0.003886saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.0037797035183757544;  saved better model in models/True_CDF_model_SILU.pth
#      10600	  0.003796	  0.003780	  0.003780saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.0035584294237196445;  saved better model in models/True_CDF_model_SILU.pth
#      11000	  0.003637	  0.003621	  0.003621saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.0035504018887877464;  saved better model in models/True_CDF_model_SILU.pth
#      11400	  0.003793	  0.003777	  0.003777saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.0035488037392497063;  saved better model in models/True_CDF_model_SILU.pth
#      11600	  0.003567	  0.003549	  0.003549saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.0034126571845263243;  saved better model in models/True_CDF_model_SILU.pth
#      12200	  0.003825	  0.003813	  0.003813saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.003318354720249772;  saved better model in models/True_CDF_model_SILU.pth
#      13600	  0.003495	  0.003479	  0.003479saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.00330257136374712;  saved better model in models/True_CDF_model_SILU.pth
#      14400	  0.003338	  0.003324	  0.003324saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.0032935384660959244;  saved better model in models/True_CDF_model_SILU.pth
#      16400	  0.003382	  0.003370	  0.003370saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.003101795446127653;  saved better model in models/True_CDF_model_SILU.pth
#      18000	  0.003649	  0.003631	  0.003631saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.0030568777583539486;  saved better model in models/True_CDF_model_SILU.pth
#      19400	  0.003138	  0.003127	  0.003127saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.0030404876451939344;  saved better model in models/True_CDF_model_SILU.pth
#      23200	  0.003390	  0.003372	  0.003372saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.0030365486163645983;  saved better model in models/True_CDF_model_SILU.pth
#      24000	  0.003141	  0.003129	  0.003129saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.002994196256622672;  saved better model in models/True_CDF_model_SILU.pth
#      28000	  0.003208	  0.003199	  0.003199saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.0029338833410292864;  saved better model in models/True_CDF_model_SILU.pth
#      30000	  0.003192	  0.003183	  0.003183saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.002909058937802911;  saved better model in models/True_CDF_model_SILU.pth
#      40000	  0.003293	  0.003274	  0.014556saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.002904225140810013;  saved better model in models/True_CDF_model_SILU.pth
#      43400	  0.003162	  0.003151	  0.004055saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.002858716296032071;  saved better model in models/True_CDF_model_SILU.pth
#      45200	  0.003161	  0.003153	  0.003437saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.0028483925852924585;  saved better model in models/True_CDF_model_SILU.pth
#      46600	  0.002979	  0.002965	  0.003317saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.002827146789059043;  saved better model in models/True_CDF_model_SILU.pth
#      47800	  0.003723	  0.003716	  0.003266saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.002826530020684004;  saved better model in models/True_CDF_model_SILU.pth
#      52600	  0.002891	  0.002878	  0.003158saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.0028073301073163748;  saved better model in models/True_CDF_model_SILU.pth
#      73400	  0.002908	  0.002895	  0.003078saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.0027923646848648787;  saved better model in models/True_CDF_model_SILU.pth
#      96400	  0.002932	  0.002921	  0.003049saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.0027921958826482296;  saved better model in models/True_CDF_model_SILU.pth
#     126000	  0.002836	  0.002823	  0.003028saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.0027765603736042976;  saved better model in models/True_CDF_model_SILU.pth
#     143800	  0.002945	  0.002927	  0.003020saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.0027728495188057423;  saved better model in models/True_CDF_model_SILU.pth
#     144800	  0.003526	  0.003522	  0.003028saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.0027660331688821316;  saved better model in models/True_CDF_model_SILU.pth
#     166400	  0.003042	  0.003026	  0.003018saving model with th string : True_CDF_model_SILU.pth
#
#
# Current valid loss: 0.0027643439825624228;  saved better model in models/True_CDF_model_SILU.pth
#     172200	  0.003041	  0.003033	  0.003019
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [117], line 12
#       6 optimizer_name=True_CDF_model_PARAMS["optimizer_name"]
#       9 optimizer_delta_r = getattr(torch.optim, str(optimizer_name))(true_CDF_model.parameters(),
#      10                                                            lr=True_CDF_model_PARAMS["starting_learning_rate"])
# ---> 12 traces_SiLU = train_true_CDF(model=true_CDF_model,
#      13               optimizer=optimizer_delta_r,
#      14               avloss=average_quadratic_loss,
#      15                             # avloss=huber_loss,
#      16               batch_size=BATCHSIZE,
#      17               n_iterations=True_CDF_model_PARAMS["n_iterations"],
#      18               traces=traces_SiLU,
#      19               step=traces_step,
#      20               window=200,
#      21                            PARAMS=True_CDF_model_PARAMS,
#      22                            pth_string=True_CDF_model_PARAMS['pth_string'])
#
# Cell In [105], line 106, in train_true_CDF(model, optimizer, avloss, batch_size, n_iterations, traces, step, window, PARAMS, pth_string)
#     100 optimizer.step()            # move one step
#     102 if ii % step == 0:
#     103
#     104
#     105     #using Harrison-like loader
# --> 106     acc_t = validate(model, avloss, train_x[:n], train_t[:n])
#     107     acc_v = validate(model, avloss, test_x[:n], test_t[:n])
#     109     model_checkpoint(model=model, current_valid_loss=acc_v, PARAMS=PARAMS, pth_string=pth_string)
#
# Cell In [105], line 36, in validate(model, avloss, inputs, targets)
#      34     t = torch.from_numpy(targets).float().to(device)
#      35     # remember to reshape!
# ---> 36     o = model(x).reshape(t.shape)
#      37 return avloss(o, t, x)
#
# File ~/anaconda3/envs/new_torch/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In [98], line 63, in True_CDF_Model.forward(self, x)
#      62 def forward(self, x):
# ---> 63     return self.model(x)
#
# File ~/anaconda3/envs/new_torch/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/new_torch/lib/python3.9/site-packages/torch/nn/modules/container.py:141, in Sequential.forward(self, input)
#     139 def forward(self, input):
#     140     for module in self:
# --> 141         input = module(input)
#     142     return input
#
# File ~/anaconda3/envs/new_torch/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/new_torch/lib/python3.9/site-packages/torch/nn/modules/linear.py:103, in Linear.forward(self, input)
#     102 def forward(self, input: Tensor) -> Tensor:
# --> 103     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %% [markdown]
# # Modelling true CDF

# %%
def load_model_true_CDF(model, PARAMS, pth_string):
    models_path = os.path.join(os.getcwd(), '../models')
    PATH=os.path.join(models_path, pth_string)
    model = True_CDF_Model(
        nfeatures=PARAMS['NFEATURES'],
        ntargets=1,
        nlayers=PARAMS["n_layers"],
        hidden_size=PARAMS["hidden_size"],
        dropout=PARAMS["dropout"]
    )
    checkpoint = torch.load(PATH)
    print('INITIATED MODEL:',  model)
    
    model.load_state_dict(checkpoint['model_state_dict'])
    print(f'loading model with th string : {pth_string}\n')    
    # print(model)
    
    return model

# %%
true_CDF_model = load_model_true_CDF(true_CDF_model, True_CDF_model_PARAMS, True_CDF_model_PARAMS['pth_string'])

df_single_point, eval_array = generate_theta_nu_single_point(theta=6, nu=10, N_points=300)
df_single_point
# Out:
# INITIATED MODEL: True_CDF_Model(
#   (model): Sequential(
#     (0): Linear(in_features=3, out_features=12, bias=True)
#     (1): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): SiLU()
#     (3): Linear(in_features=12, out_features=12, bias=True)
#     (4): SiLU()
#     (5): Linear(in_features=12, out_features=12, bias=True)
#     (6): SiLU()
#     (7): Linear(in_features=12, out_features=12, bias=True)
#     (8): SiLU()
#     (9): Linear(in_features=12, out_features=12, bias=True)
#     (10): SiLU()
#     (11): Linear(in_features=12, out_features=12, bias=True)
#     (12): SiLU()
#     (13): Linear(in_features=12, out_features=1, bias=True)
#   )
# )
# loading model with th string : True_CDF_model_SILU.pth
#      theta    nu        q    lambda  delta_C  pred_CDF  true_CDF   delta_r
# 41     6.0  10.0  0.08487   0.00000  0.05225   0.04828  0.023333  0.024947
# 222    6.0  10.0  0.78942   0.00000 -0.04694   0.04828  0.023333  0.024947
# 9      6.0  10.0  0.05764   0.00000 -0.02753   0.04828  0.023333  0.024947
# 19     6.0  10.0  0.05803   0.00000  0.00551   0.04828  0.023333  0.024947
# 66     6.0  10.0  0.16636   0.00000  0.05437   0.04828  0.023333  0.024947
# ..     ...   ...      ...       ...      ...       ...       ...       ...
# 111    6.0  10.0  0.36164  10.16362  0.00959   0.99814  0.990000  0.008140
# 212    6.0  10.0  0.76241  10.16362 -0.05337   0.99814  0.990000  0.008140
# 12     6.0  10.0  0.05764  10.70480 -0.01750   0.99891  0.993333  0.005577
# 181    6.0  10.0  0.60005  11.09617  0.00530   0.99926  0.996667  0.002593
# 99     6.0  10.0  0.33025  20.00000  0.00085   0.99999  1.000000 -0.000010
#
# [300 rows x 8 columns]

# %%
eval_array[:5]
# Out:
# array([[ 9.     , 14.     ,  0.     ],
#        [ 9.     , 14.     ,  0.     ],
#        [ 9.     , 14.     ,  0.     ],
#        [ 9.     , 14.     ,  0.     ],
#        [ 9.     , 14.     ,  0.04286]])

# %% [markdown]
# # plot true CDF model pandel for CDFs with conformal band

# %%
fig, ax = plt.subplots(2,2,figsize=(10,10))
ax = ax.ravel()

for ind, (theta, nu) in enumerate(points):
    df_single_point, eval_array = generate_theta_nu_single_point(theta=theta, nu=nu, N_points=300)
    eval_array_tensor = torch.Tensor(eval_array)
    true_CDF = df_single_point['true_CDF'].to_numpy().flatten()
    lambda_ = df_single_point['lambda'].to_numpy().flatten()
    ax[ind].plot(lambda_, true_CDF, label=r'Empirical $F$',color='darkblue', linewidth=3, linestyle='--')
    # ax[ind].hist(lambda_, bins=30, density=True, cumulative=True, histtype='stepfilled', edgecolor='black', color = 'powderblue')
    CDF_hat = true_CDF_model(eval_array_tensor).view(-1).detach().numpy()

    Ncal = len(true_CDF)
    CL=0.683

    alpha_freq = np.ceil((Ncal+1)*(CL))/Ncal

    scores = np.abs(true_CDF-CDF_hat)
    print(scores.mean(), scores.std())

    qhat = np.quantile(scores, alpha_freq)


    lower_bound = np.array(CDF_hat-qhat)
    upper_bound = np.array(CDF_hat+qhat)


    ax[ind].plot(lambda_, CDF_hat, label=r'$\hat{F}$', linewidth=3, color='red')

    ax[ind].fill_between(lambda_, y1=lower_bound, 
                     y2=upper_bound, 
                     color='k', 
                     alpha=0.25, label = 'Conformal 0.68\% CI')

    ymin, ymax = 0, 1.2
    xmin, xmax = 0, 10
    ax[ind].set_ylim(ymin,ymax)
    ax[ind].set_xlim(xmin,xmax)
    ax[ind].set_ylabel(r'$F$')
    ax[ind].set_xlabel(r'$\lambda$')
    ax[ind].legend(fontsize=15)
        #annotate
    xwid = (xmax-xmin)/12
    ywid = (ymax-ymin)/12
    xpos = xmin + 3*xwid
    ypos = ymin + ywid*2
    ax[ind].text(3.5, 0.6,
        r'$ \mu = %.2f, \nu = %.2f$' % (theta, nu),
        fontsize=ftsize)
plt.savefig('../images/OnOff_True_CDF_CDFs.pdf')
plt.tight_layout()
plt.show()
# Out:
# 0.027632581559485853 0.0196953220176619
# 0.04650485455890497 0.03440008573008249
# 0.02235416167742676 0.017535627983038475
# 0.02191584201455116 0.01532432478521372

# %% [markdown]
# Take empirical PDF from the empirical CDFs $F$ as
# $$ f^{emp}_i = \frac{F_{i+1} - F_i}{\lambda_{i+1}-\lambda_i}$$

# %%
fig, ax = plt.subplots(2,2,figsize=(10,10))
ax = ax.ravel()
tmodel = TrainedModel(true_CDF_model)

def coarse_grain_lambda(lambda_, theta, nu, xbins=25, xmin=0, xmax=10):
    Y, edges = np.histogram(lambda_, bins=xbins, range=(xmin, xmax), density=True)
    h = edges[1]-edges[0]# bin width
    # Y = np.cumsum(Y) * h# are (CDF_)
    x = (edges[1:]+edges[:-1])/2#bin centers
    X = np.empty((len(x), 3))
    X[:,0] = np.ones_like(theta)*theta
    X[:,1] = np.ones_like(nu)*nu
    X[:,2] = np.linspace(x[0], x[-1],len(x))
    return Y, X, x

for ind, (theta, nu) in enumerate(points):
    df_single_point, eval_array = generate_theta_nu_single_point(theta=theta, nu=nu, N_points=1000)
    eval_array_tensor = torch.Tensor(eval_array)
    true_CDF = df_single_point['true_CDF'].to_numpy().flatten()
    lambda_ = df_single_point['lambda'].to_numpy().flatten()
    # CDF_coarse_grained = np.linspace(0,1,26)#CDF
    # test_statistic_coarse_grained = np.quantile(lambda_, probabilities_lambda)#lambda
    # empirical_PDF = []
    # for i in range(len(probabilities_lambda)-1):
    #     lambda_i = test_statistic_coarse_grained[i]
    #     lambda_i_plus_1 = test_statistic_coarse_grained[i+1]
    #     true_CDF_i = CDF_coarse_grained[i]
    #     true_CDF_i_plus_1 = CDF_coarse_grained[i+1]
    #     empirical_PDF_i = (true_CDF_i_plus_1-true_CDF_i)/(lambda_i_plus_1 - lambda_i)
    #     empirical_PDF.append(empirical_PDF_i)
    # empirical_PDF.append(empirical_PDF[-1])
    # empirical_PDF = np.array(empirical_PDF)
    # print(test_statistic_coarse_grained)
    
    # ax[ind].plot(test_statistic_coarse_grained, empirical_PDF, label=r'Empirical $F$',color='darkblue', linewidth=3, linestyle='--')
    BINS=30
    empirical_PDF, coarse_grained_X, centers =  coarse_grain_lambda(lambda_, theta, nu, xbins=BINS, xmin=0, xmax=10)
    
    ax[ind].hist(lambda_, bins=BINS, density=True, histtype='stepfilled', edgecolor='black', color = 'powderblue', range=(0,10))

    
    
    PDF_hat = tmodel.pdf(coarse_grained_X)
    
    ax[ind].plot(centers, PDF_hat, label=r'$\hat{f} = \partial \hat{F} / \partial \lambda$', linewidth=3, color='red')
    # ax[ind].plot(centers, empirical_PDF, label=r'Empirical $f$', linewidth=3, color='blue', linestyle='--')
    Ncal = len(true_CDF)
    CL=0.683

    alpha_freq = np.ceil((Ncal+1)*(CL))/Ncal

    scores = np.abs(empirical_PDF-PDF_hat)
    # print(scores.mean(), scores.std())

    qhat = np.quantile(scores, alpha_freq)


    lower_bound = np.array(PDF_hat-qhat)
    upper_bound = np.array(PDF_hat+qhat)

    ax[ind].fill_between(centers, y1=lower_bound, 
                     y2=upper_bound, 
                     color='k', 
                     alpha=0.25, label = 'conformal 0.68\% CI')

    ymin, ymax = 0, 1
    xmin, xmax = 0.01, 10
    ax[ind].set_ylim(ymin,ymax)
    ax[ind].set_xlim(xmin,xmax)
    ax[ind].set_ylabel(r'$f$')
    ax[ind].set_xlabel(r'$\lambda$')
    ax[ind].legend(fontsize=15)
        #annotate
    xwid = (xmax-xmin)/12
    ywid = (ymax-ymin)/12
    xpos = xmin + 3*xwid
    ypos = ymin + ywid*2
    ax[ind].text(3.5, 0.6,
        r'$ \mu = %.2f, \nu = %.2f$' % (theta, nu),
        fontsize=ftsize)
plt.savefig('../images/OnOff_True_CDF_PDFs.pdf')
plt.tight_layout()
plt.show()

# %% [markdown]
# # NN trained over all points (coarse-grained)

# %%
eval_df, eval_array = generate_theta_nu_single_point_coarse_grain(tmodel= tmodel, theta=15, nu=10)
eval_df =  pd.DataFrame(eval_df, columns=['theta', 'nu', 'lambda', 'residual'])
eval_df=eval_df.sort_values(by='lambda')
lambda_=eval_df['lambda'].values
exact_res=eval_df['residual'].values
plt.plot(lambda_, exact_res, label='exact residual')

eval_array_tensor = torch.Tensor(eval_array)
delta_r_hat = untrained_Delta_r_model(eval_array_tensor).detach().numpy()
plt.plot(lambda_, delta_r_hat, label='predicted residul')

plt.legend()
plt.show()

# %% [markdown]
# # NN trained over all points (not coarse-grained)

# %%
df_single_point, eval_array = generate_theta_nu_single_point(theta=13, nu=10, N_points=100)
df_single_point

# %%
df_single_point, eval_array = generate_theta_nu_single_point(theta=10, nu=10, N_points=100)

eval_array_tensor = torch.Tensor(eval_array)
delta_r = df_single_point['delta_r'].to_numpy()
lambda_ = df_single_point['lambda'].to_numpy()
delta_r_hat = untrained_Delta_r_model(eval_array_tensor).detach().numpy()
plt.plot(lambda_, delta_r, label=r'exact $\Delta r$')
plt.plot(lambda_, delta_r_hat, label=r'predicted $\Delta r$')
plt.ylabel(r'$\Delta r = F_{pred}-F_{true}$')
plt.xlabel(r'$\lambda$')
plt.legend()
plt.show()

# %%
true_CDF_res = true_CDF.flatten() - CDF_hat.flatten()
plt.plot(lambda_, true_CDF_res)
plt.show()

# %%
def plot_all_true_CDF(lambda_, theta, nu, ax_l, MLE):
    """Histogram the CDF of  lambda_t = -2log(Lp(theta)/Lp(theta_hat)), 
    for a given (fixed) theta and nu.
    Also, plot the actual CDF of a chi^2 distribution with 1 free parameter 
    (since only theta is left after we profile nu) """
    ftsize = 16; xmin= 0; xmax= 10
    ymin= 0; ymax= 1
    x_range = (xmin, xmax)
    y_range = (ymin, ymax)
    X = np.empty((len(lambda_), 3))
    X[:,0] = np.ones_like(theta)*theta
    X[:,1] = np.ones_like(nu)*nu
    
    X[:,2] = np.linspace(0,10,len(lambda_))
    BINS=50
    if MLE==True:
        tmodel_ALFFI = TrainedModel(trained_SiLU_model_MLE)
    else:
        tmodel_ALFFI = TrainedModel(trained_SiLU_model_nonMLE)
        
    tmodel_true_CDF = TrainedModel(untrained_Delta_r_model)
    
    ax_l[0].set_ylabel(r'$F(\lambda)$', fontsize=ftsize)
    ##########HISTOGRAM CDF OF LAMBDA####################
    
    ax_l[0].hist(lambda_, bins=BINS, range=x_range,
    color=(0.8,0.8,0.9),
    density=True, cumulative=True,
    histtype='stepfilled', edgecolor='black', label=r'$F(\lambda)$')
    ############################################################
    ########### HISTOGRAM CDF OF THE CHI2 OF OF X WITH 1 DOF
    #x is not theta, that's the whole point of Wilks thm, x is an arbitrary RV
    x = np.arange(0, xmax, 0.2)
    y = st.chi2.cdf(x, 2)
    ax_l[0].plot(x, y, color='green',
    linewidth=2, label=r'$F(\chi^2_2)$')
    cdf = tmodel.cdf(X)
    ax_l[0].plot(X[:,2], cdf, label='$\hat{F}_{ALFFI}(\lambda)$', color='red')
    
    tmodel_true_CDF_cdf = tmodel_true_CDF.cdf(X)
    ax_l[0].plot(X[:,2], tmodel_true_CDF_cdf, label='$\hat{F}_{true \ CDF}(\lambda)$', color='blue')
    
    
    ax_l[1].set_ylabel(r'$f(\lambda)$', fontsize=ftsize)
    ax_l[1].hist(lambda_, bins=BINS, range=x_range,density=True,
    color=(0.8,0.8,0.9),
    histtype='stepfilled', edgecolor='black', label=r'$f(\lambda)$')
    
    x = np.arange(0, xmax, 0.2)
    y = st.chi2.pdf(x, 2)
    ax_l[1].plot(x, y, color='green',
    linewidth=2, label=r'$f(\chi^2_2)$')
    
    ax_l[2].set_ylabel(r'$f(\lambda)= \partial \hat{F} / \partial \lambda$', fontsize=ftsize)
    ax_l[2].hist(lambda_, bins=BINS, range=x_range,density=True,
    color=(0.8,0.8,0.9),
    histtype='stepfilled', edgecolor='black', 
                 label=r'$f(\lambda)$'
                )


    pdf = tmodel.pdf(X)
    ax_l[2].plot(X[:,2], pdf, label='$\partial \hat{F}_{ALFFI} / \partial \lambda$', color = 'r', linestyle='--', linewidth=3 )

    tmodel_true_CDF_pdf = tmodel_true_CDF.pdf(X)
    ax_l[2].plot(X[:,2], tmodel_true_CDF_pdf, label='$\partial \hat{F}_{true \ CDF} / \partial \lambda$', color='green', linewidth=3)

    
    pdf_deriv = tmodel.numerical_deriv(X)
    ax_l[2].plot(X[:,2], pdf_deriv, label='numerical $\partial \hat{F}_{ALFFI} / \partial \lambda$', color='black', linestyle='--', linewidth=3)
    
    ############################################################
    
    # annotate
    xwid = (xmax-xmin)/12
    ywid = (ymax-ymin)/12
    xpos = xmin + 3*xwid
    ypos = ymin + ywid*2
    for i in range(len(ax_l)):
        ax_l[i].set_xlim(x_range); ax_l[i].set_ylim(y_range)
        ax_l[i].set_xlabel(r'$\lambda \left(\mu,\nu \mid n, m \right)$',fontsize=ftsize-2)
        ax_l[i].text(xpos, ypos,
        r'$ \mu = %.2f, \nu = %.2f$' % (theta, nu),
        fontsize=ftsize-3)
        ax_l[i].legend(loc='upper right',fontsize=13)

# %%
#points=(theta,nu)
chi2_exp_size=40000

points_1 = (10, 4)

MLE=False
_, _ , lambda_1 = run_sim(theta=points_1[0], nu=points_1[1], MLE=MLE, lambda_size=chi2_exp_size)

fig, ax = plt.subplots(1,3, figsize=(10,5), sharey=True)

plt.subplots_adjust(wspace=0.3)
# plot_one(lambda_1, points_1[0], points_1[1], ax)
plot_all_true_CDF(lambda_1, points_1[0], points_1[1], ax, MLE=MLE)

fig.suptitle(r'MLE=%s; $N_{sample}$=%s' % \
             (  str(MLE), str(int(chi2_exp_size))), fontsize=25); 



SAVE=False
if SAVE:
    plt.savefig('../images/Wilk_agreement_MLE_%s_N_%s.pdf' % (str(MLE), str(chi2_exp_size) ))
plt.show()

# %% [markdown]
# # NN trained over single point

# %%
df_single_point, eval_array = generate_theta_nu_single_point(theta=19, nu=5, N_points=100)

eval_array_tensor = torch.Tensor(eval_array)
delta_r = df_single_point['delta_r'].to_numpy()
lambda_ = df_single_point['lambda'].to_numpy()
delta_r_hat = untrained_Delta_r_model(eval_array_tensor).detach().numpy()
plt.plot(lambda_, delta_r, label=r'exact $\Delta r$')
plt.plot(lambda_, delta_r_hat, label=r'predicted $\Delta r$')
plt.ylabel(r'$\Delta r = F_{pred}-F_{true}$')
plt.xlabel(r'$\lambda$')
plt.legend()
plt.show()
